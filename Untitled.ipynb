# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['lines.linewidth'] = 2
plt.grid()
mlp_permutator_x = [25, 55, 88]
mlp_permutator_y = [81.5, 82.7, 83.2]
plt.plot(mlp_permutator_x, mlp_permutator_y, marker='^', c='green', label='permutator',linestyle='-.', markersize=10)
mlp_spatialshift_mlpx = [25, 55]
mlp_spatialshift_mlpy = [82, 83.6]
plt.plot(mlp_spatialshift_mlpx, mlp_spatialshift_mlpy, marker='^', c='blue', label='spatialshiftV2',linestyle='-.', markersize=10)
cyclemlp_x = [15, 27, 38, 52, 76]
cyclemlp_y = [78.9, 81.6, 82.4, 83, 83.2]
plt.plot(cyclemlp_x, cyclemlp_y, marker='^', c='red', label='cycle-mlp',linestyle='-.', markersize=10)
gmlp_x = [6, 20, 73]
gmlp_y = [72.3, 79.6, 81.6]
plt.plot(gmlp_x, gmlp_y, marker='^', c='pink', label='gmlp',linestyle='-.', markersize=10)

mlpmixer_x = [59]
mlpmixer_y = [77.3]
plt.plot(mlpmixer_x, mlpmixer_y, marker='^', c='tan', label='mlp-mixer',linestyle='-.', markersize=10)
resmlp_x = [15, 30, 116]
resmlp_y = [76.6, 79.4, 81]
plt.plot(resmlp_x, resmlp_y, marker='o', c='bisque', label='res-mlp',linestyle='-.', markersize=10)
vip_x = [30, 25, 55, 88]
vip_y = [80.7, 81.5, 82.7, 83.2]
plt.plot(vip_x, vip_y, marker='o', c='y', label='Vip',linestyle='-.', markersize=10)
as_mlpx = [28, 50, 88]
as_mlpy = [81.3, 83.1, 83.3]
plt.plot(as_mlpx, as_mlpy, marker='o', c='tomato', label='as-mlp',linestyle='-.', markersize=10)
raft_mlpx = [44, 58]
raft_mlpy = [76.9, 78]
plt.plot(raft_mlpx, raft_mlpy, marker='o', c='peachpuff', label='raft-mlp',linestyle='-.', markersize=10)
sparesmlpx = [24, 49, 66]
sparesmlpy = [81.9, 83.1, 83.3]
plt.plot(sparesmlpx, sparesmlpy, marker='o', c='greenyellow', label='sparse-mlp',linestyle='-.', markersize=10)
convmlpx = [9, 17, 43]
convmlpy = [76.8, 79, 80.2]
plt.plot(convmlpx, convmlpy, marker='o', c='skyblue', label='conv-mlp',linestyle='-.', markersize=10)
cyclemlpx = [28, 50, 88]
cyclemlpy = [81.3, 82.9, 83.4]
plt.plot(cyclemlpx, cyclemlpy, marker='o', c='cyan', label='cycle-mlp',linestyle='-.', markersize=10)
hiremlpx = [18, 33, 58, 96]
hiremlpy = [79.7, 82.1, 83.2, 83.8]
plt.plot(hiremlpx, hiremlpy, marker='o', c='fuchsia', label='hire-mlp',linestyle='-.', markersize=10)
poolformerx = [11.9, 21.4, 30.8, 56.1, 73.4]
poolformery = [77.2, 80.3, 81.4, 82.1, 82.5]
plt.plot(poolformerx, poolformery, marker='o', c='orchid', label='poolformer',linestyle='-.', markersize=10)
dyna_x = [26, 57, 97]
dyna_y = [82.7, 83.7, 84.3]
plt.plot(dyna_x, dyna_y, marker='o', c='slateblue', label='dynamixer',linestyle='-.', markersize=10)
msmlp_x = [28, 50, 88]
msmlp_y = [82.1, 83.4, 83.8]
plt.plot(msmlp_x, msmlp_y, marker='o', c='tomato', label='ms-mlp',linestyle='-.', markersize=10)
wavemlp_x = [17, 30, 44, 63]
wavemlp_y = [80.6, 82.6, 83.4, 83.6]
plt.plot(wavemlp_x, wavemlp_y, marker='*', c='olive', label='wave-mlp',linestyle='-.', markersize=10)

plt.xlabel("Number of Parameters(M)")
plt.ylabel("Top1 Accuracy (%) on ImageNet-1K")

plt.legend()
plt.show()
